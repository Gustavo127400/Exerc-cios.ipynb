# %% [markdown]
# # **Exercícios**
#
# Python com Pandas
# Análise de Vendas
#
# I. Calcule o valor total de cada venda:
#
# II. Adicione uma nova coluna ao DataFrame chamada valor_total que seja o resultado da multiplicação da quantidade pelo preço unitário.
# Valor total vendido por produto:
#
# III. Agrupe o DataFrame por produto e calcule a soma dos valores totais de cada produto.
# Total de produtos vendidos:
#
# IV. Calcule o total de produtos vendidos somando todas as quantidades.
# Cliente que mais gastou:
#
# V. Agrupe as vendas por cliente (id_cliente) e calcule o total gasto por cada um. Identifique o cliente com o maior gasto.
# Filtrar vendas de Março de 2024:
#
# VI. Extraia as vendas que ocorreram entre 1º de março de 2024 e 31 de março de 2024.
# Manipulação de Dados

# %% [markdown]
#  # **Importação dos dados**

# %%
import pandas as pd

data = {
    'id_venda': [1, 2, 3, 4, 5, 6, 7, 8],
    'id_cliente': [1, 2, 3, 1, 4, 2, 5, 3],
    'produto': ['Notebook', 'Smartphone', 'Tablet', 'Monitor', 'Teclado', 'Notebook', 'Smartphone', 'Monitor'],
    'quantidade': [1, 2, 1, 2, 3, 1, 1, 1],
    'preco_unitario': [3000.00, 1500.00, 1200.00, 800.00, 150.00, 3200.00, 1800.00, 850.00],
    'data_venda': pd.to_datetime(['2024-01-10', '2024-01-12', '2024-02-05', '2024-02-20', '2024-03-01', '2024-03-10', '2024-03-15', '2024-04-01'])
}

df_vendas = pd.DataFrame(data)

# %% [markdown]
# # **Nosso DataFrame**
#
# ```
# df_vendas
# ```

# %%
df_vendas
# Out:
#    id_venda  id_cliente     produto  quantidade  preco_unitario data_venda
# 0         1           1    Notebook           1          3000.0 2024-01-10
# 1         2           2  Smartphone           2          1500.0 2024-01-12
# 2         3           3      Tablet           1          1200.0 2024-02-05
# 3         4           1     Monitor           2           800.0 2024-02-20
# 4         5           4     Teclado           3           150.0 2024-03-01
# 5         6           2    Notebook           1          3200.0 2024-03-10
# 6         7           5  Smartphone           1          1800.0 2024-03-15
# 7         8           3     Monitor           1           850.0 2024-04-01

# %% [markdown]
# # **I. Calcule o valor total de cada venda:**

# %%
 df_vendas['valor_total'] = df_vendas['quantidade'] * df_vendas['preco_unitario'] # Nova váriavel que calcula o valor total.
df_vendas
# Out:
#    id_venda  id_cliente     produto  quantidade  preco_unitario data_venda  \
# 0         1           1    Notebook           1          3000.0 2024-01-10
# 1         2           2  Smartphone           2          1500.0 2024-01-12
# 2         3           3      Tablet           1          1200.0 2024-02-05
# 3         4           1     Monitor           2           800.0 2024-02-20
# 4         5           4     Teclado           3           150.0 2024-03-01
# 5         6           2    Notebook           1          3200.0 2024-03-10
# 6         7           5  Smartphone           1          1800.0 2024-03-15
# 7         8           3     Monitor           1           850.0 2024-04-01
#
#    valor_total
# 0       3000.0
# 1       3000.0
# 2       1200.0
# 3       1600.0
# 4        450.0
# 5       3200.0
# 6       1800.0
# 7        850.0

# %% [markdown]
# # **II. Adicione uma nova coluna ao DataFrame chamada valor_total que seja o resultado da multiplicação da quantidade pelo preço unitário. Valor total vendido por produto:**

# %%
 df_vendas['valor_total'] = df_vendas['quantidade'] * df_vendas['preco_unitario'] # Nova váriavel que calcula o valor total.
df_vendas
# Out:
#    id_venda  id_cliente     produto  quantidade  preco_unitario data_venda  \
# 0         1           1    Notebook           1          3000.0 2024-01-10
# 1         2           2  Smartphone           2          1500.0 2024-01-12
# 2         3           3      Tablet           1          1200.0 2024-02-05
# 3         4           1     Monitor           2           800.0 2024-02-20
# 4         5           4     Teclado           3           150.0 2024-03-01
# 5         6           2    Notebook           1          3200.0 2024-03-10
# 6         7           5  Smartphone           1          1800.0 2024-03-15
# 7         8           3     Monitor           1           850.0 2024-04-01
#
#    valor_total
# 0       3000.0
# 1       3000.0
# 2       1200.0
# 3       1600.0
# 4        450.0
# 5       3200.0
# 6       1800.0
# 7        850.0

# %% [markdown]
# # III.  **Agrupe o DataFrame por produto e calcule a soma dos valores totais de cada produto. Total de produtos vendidos:**

# %%
count_produtos = df_vendas.groupby('produto')['valor_total'].count()# count(): Conta o número de ocorrências.
mean_produtos = df_vendas.groupby('produto')['valor_total'].mean()# mean(): Calcula a média dos valores.
min_produtos = df_vendas.groupby('produto')['valor_total'].min()# min(): Encontra o valor mínimo.
max_produtos = df_vendas.groupby('produto')['valor_total'].max()# max(): Encontra o valor máximo.
std_produtos = df_vendas.groupby('produto')['valor_total'].std()# std(): Calcula o desvio padrão.
sum_produtos = df_vendas.groupby('produto')['valor_total'].sum()# sum(): Soma todos os valores.

sum_produtos
# Out:
# produto
# Monitor       2450.0
# Notebook      6200.0
# Smartphone    4800.0
# Tablet        1200.0
# Teclado        450.0
# Name: valor_total, dtype: float64

# %% [markdown]
# # **IV. Calcule o total de produtos vendidos somando todas as quantidades. Cliente que mais gastou:**

# %%
sum_clientes = df_vendas.groupby('id_cliente')['valor_total'].sum()
print("Segundo nosso dataFrame(IV), o id do cliente que mais gastou foi: {}".format((sum_clientes.idxmax())))
# Out:
# Segundo nosso dataFrame(IV), o id do cliente que mais gastou foi: 2

# %% [markdown]
# # **V. Agrupe as vendas por cliente (id_cliente) e calcule o total gasto por cada um. Identifique o cliente com o maior gasto. Filtrar vendas de Março de 2024:**

# %%
vendas_marco = df_vendas[(df_vendas['data_venda'].dt.month == 3) & (df_vendas['data_venda'].dt.year == 2024)]
print("Segundo nosso dataFrame(V), o id do cliente que mais gastou no mês de março(3) foi: {}".format((vendas_marco['id_cliente'].idxmax())))
# Out:
# Segundo nosso dataFrame(V), o id do cliente que mais gastou no mês de março(3) foi: 6

# %% [markdown]
# # **VI. Extraia as vendas que ocorreram entre 1º de março de 2024 e 31 de março de 2024. Manipulação de Dados**

# %%
vendas_marco = df_vendas[(df_vendas['data_venda'].dt.month == 3) & (df_vendas['data_venda'].dt.year == 2024)]
vendas_marco
# Out:
#    id_venda  id_cliente     produto  quantidade  preco_unitario data_venda  \
# 4         5           4     Teclado           3           150.0 2024-03-01
# 5         6           2    Notebook           1          3200.0 2024-03-10
# 6         7           5  Smartphone           1          1800.0 2024-03-15
#
#    valor_total
# 4        450.0
# 5       3200.0
# 6       1800.0
